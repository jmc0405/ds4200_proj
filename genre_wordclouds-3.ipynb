# %% [markdown]
# # Genre & Artist Word Clouds — Northeastern Music Survey
# Reads the raw survey CSV and generates all word clouds automatically — no manual data entry.
#
# **Sections:**
# 1. Install & import
# 2. Load & clean data
# 3. Parse counts
# 4. Helper functions
# 5. Overall genre clouds
# 6. Genre clouds by college
# 7. Overall artist cloud
# 8. Artist clouds by college

# %% [markdown]
# ## 1. Install & import

# %%
# %pip install wordcloud matplotlib pandas --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import ast
import re
from collections import Counter

import matplotlib.pyplot as plt
import pandas as pd
from wordcloud import WordCloud

# %matplotlib inline
plt.rcParams['figure.dpi'] = 130

# %% [markdown]
# ## 2. Load & clean data
# Update `FILE_PATH` if your CSV lives somewhere else.

# %%
FILE_PATH = "/Users/kathleenwang/Documents/DS4200/music project/cleaned_music_data.csv"  # <- update if needed

df = pd.read_csv(FILE_PATH)

df.columns = [
    "major", "college",
    "genre1", "genre2", "genre3",
    "top_artists",
    "hours_per_day", "minutes_2025",
    "concerts_attended", "avg_ticket_spend",
    "max_ticket", "concert_genres", "fav_venue"
]

# Shorten college names for cleaner plot titles
COLLEGE_LABELS = {
    "Khoury College of Computer Sciences":      "Khoury (CS / Data Science)",
    "D'Amore-McKim School of Business":          "D'Amore-McKim (Business)",
    "College of Engineering":                    "College of Engineering",
    "College of Science":                        "College of Science",
    "Bouve College of Health Sciences":          "Bouve (Health Sciences)",
    "College of Social Science and Humanities":  "Social Science & Humanities",
    "College of Arts, Media, and Design":        "Arts, Media & Design",
}
df["college_short"] = df["college"].map(COLLEGE_LABELS).fillna(df["college"])

print(f"Loaded {len(df)} responses across {df['college_short'].nunique()} colleges.")
df.head(3)
# Out:
# Loaded 101 responses across 7 colleges.
#                     major                                   college   genre1  \
# 0  Mechanical Engineering                    College of Engineering  Hip-Hop
# 1       Political Science  College of Social Science and Humanities      R&B
# 2        Computer Science       Khoury College of Computer Sciences      R&B
#
#   genre2 genre3                                        top_artists  \
# 0  Indie   Jazz  ['kanye west', 'cosmos sheldrake', 'miles davis']
# 1    Pop   Rock        ['daniel caesar', 'the 1975', 'yerin baek']
# 2    Pop  Indie             ['enhypen', 'dpr ian', 'silence wang']
#
#   hours_per_day minutes_2025 concerts_attended avg_ticket_spend  max_ticket  \
# 0          0.25           87                 0                0        25.0
# 1             3        34000                 3              150       200.0
# 2             6        18000                 1              200       350.0
#
#   concert_genres      fav_venue                college_short
# 0        Hip-Hop  No preference       College of Engineering
# 1      Pop, Rock  No preference  Social Science & Humanities
# 2            Pop  No preference   Khoury (CS / Data Science)

# %% [markdown]
# ## 3. Parse counts
# All frequency dictionaries are built directly from the dataframe — nothing is hardcoded.

# %%
def clean_genre(g):
    """Normalise a genre string: strip whitespace, title-case, merge aliases."""
    if not isinstance(g, str):
        return None
    g = g.strip().title()
    aliases = {
        "Hip-Hop": ["Hip Hop", "Hiphop", "Hip-Hop"],
        "R&B":     ["R&Amp;B", "Rnb", "R And B"],
        "K-Pop":   ["Kpop", "K Pop", "K-Pop"],
        "Electronic": ["Edm", "Electronic Dance"],
    }
    for canonical, variants in aliases.items():
        if g in variants:
            return canonical
    return g


def parse_artists(raw):
    """Parse an artist list string into a Python list of title-cased names."""
    if not isinstance(raw, str):
        return []
    try:
        artists = ast.literal_eval(raw)
        return [a.strip().title() for a in artists if isinstance(a, str) and a.strip()]
    except Exception:
        raw = re.sub(r"[\[\]'\"]", "", raw)
        return [a.strip().title() for a in raw.split(",") if a.strip()]


# Genre frequency dicts
top1_genres = dict(
    Counter(clean_genre(g) for g in df["genre1"] if clean_genre(g))
)

all_top3_genres = dict(
    Counter(
        clean_genre(g)
        for col in ["genre1", "genre2", "genre3"]
        for g in df[col]
        if clean_genre(g)
    )
)

concert_genre_counts = Counter()
for entry in df["concert_genres"].dropna():
    for g in str(entry).split(","):
        g = clean_genre(g)
        if g and g.lower() not in ("none", "n/a", "na"):
            concert_genre_counts[g] += 1
concert_genres = dict(concert_genre_counts)

# Artist frequency dicts
all_artists = dict(
    Counter(
        artist
        for raw in df["top_artists"]
        for artist in parse_artists(raw)
    )
)

# Per-college breakdowns
college_genres = {}
college_artists = {}

for college, group in df.groupby("college_short"):
    college_genres[college] = dict(
        Counter(
            clean_genre(g)
            for col in ["genre1", "genre2", "genre3"]
            for g in group[col]
            if clean_genre(g)
        )
    )
    college_artists[college] = dict(
        Counter(
            artist
            for raw in group["top_artists"]
            for artist in parse_artists(raw)
        )
    )

print("Top genres (all top-3):", sorted(all_top3_genres.items(), key=lambda x: -x[1])[:8])
print("\nTop artists overall:",   sorted(all_artists.items(),     key=lambda x: -x[1])[:8])
# Out:
# Top genres (all top-3): [('R&B', 59), ('Pop', 58), ('Indie', 39), ('Hip-Hop', 33), ('Electronic', 28), ('Rap', 25), ('Rock', 17), ('K-Pop', 13)]
#
# Top artists overall: [('Daniel Caesar', 8), ('Sza', 7), ('Drake', 7), ('Don Toliver', 7), ('Knock2', 6), ('Keshi', 5), ('Olivia Dean', 5), ('Tyler The Creator', 4)]

# %% [markdown]
# ## 4. Helper functions

# %%
COLLEGE_COLORS = {
    "Khoury (CS / Data Science)":    "#7F77DD",
    "D'Amore-McKim (Business)":       "#1D9E75",
    "College of Engineering":         "#EF9F27",
    "College of Science":             "#D85A30",
    "Bouve (Health Sciences)":        "#378ADD",
    "Social Science & Humanities":    "#639922",
    "Arts, Media & Design":           "#D4537E",
}


def make_single_color_func(hex_color):
    """WordCloud color_func that shades words in a single hue by font size."""
    r, g, b = int(hex_color[1:3], 16), int(hex_color[3:5], 16), int(hex_color[5:7], 16)

    def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
        factor = min(0.4 + 0.6 * (font_size / 80), 1.0)
        return f"rgb({int(r*factor)},{int(g*factor)},{int(b*factor)})"

    return color_func


def build_wc(freq_dict, colormap=None, color_func=None,
             max_words=60, width=800, height=420):
    """Build and return a WordCloud from a frequency dictionary."""
    wc = WordCloud(
        width=width,
        height=height,
        background_color="white",
        max_words=max_words,
        prefer_horizontal=0.85,
        colormap=colormap,
        color_func=color_func,
        relative_scaling=0.55,
        min_font_size=12,
    )
    wc.generate_from_frequencies(freq_dict)
    return wc


def cloud_grid(data_dict, title, filename, ncols=3, max_words=40):
    """Render a grid of word clouds, one per key in data_dict."""
    items = [(k, v) for k, v in data_dict.items() if v]
    nrows = (len(items) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=(18, nrows * 5.5))
    fig.suptitle(title, fontsize=16, fontweight="bold", y=1.01)
    axes_flat = axes.flatten() if hasattr(axes, 'flatten') else axes

    for i, (label, freq) in enumerate(items):
        ax = axes_flat[i]
        hex_col = COLLEGE_COLORS.get(label, "#888888")
        wc = build_wc(freq, color_func=make_single_color_func(hex_col), max_words=max_words)
        ax.imshow(wc, interpolation="bilinear")
        ax.axis("off")
        ax.set_title(label, fontsize=12, fontweight="500", pad=8, color=hex_col)

    for j in range(len(items), len(axes_flat)):
        axes_flat[j].set_visible(False)

    plt.tight_layout()
    plt.savefig(filename, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"Saved -> {filename}")

# %% [markdown]
# ## 5. Overall genre clouds
# Three side-by-side clouds: top-ranked genre, all top-3 picks, and concert genres.

# %%
overall_data = [
    ("Top genre only (rank #1)", top1_genres,    "Purples"),
    ("All top 3 genre picks",    all_top3_genres, "Blues"),
    ("Concert genres attended",  concert_genres,  "Greens"),
]

fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle("Northeastern Music Survey — Genre Word Clouds",
             fontsize=16, fontweight="bold", y=1.01)

for ax, (title, data, cmap) in zip(axes, overall_data):
    wc = build_wc(data, colormap=cmap)
    ax.imshow(wc, interpolation="bilinear")
    ax.axis("off")
    ax.set_title(title, fontsize=13, fontweight="500", pad=10)

plt.tight_layout()
plt.savefig("genre_clouds_overall.png", dpi=150, bbox_inches="tight")
plt.show()
print("Saved -> genre_clouds_overall.png")
# Out:
# Saved -> genre_clouds_overall.png

# %% [markdown]
# ## 6. Genre clouds by college

# %%
cloud_grid(
    data_dict=college_genres,
    title="Genre Word Clouds by College",
    filename="genre_clouds_by_college.png",
    max_words=40,
)
# Out:
# Saved -> genre_clouds_by_college.png

# %% [markdown]
# ## 7. Overall artist cloud
# All artists mentioned across every student's top-3 picks, sized by number of mentions.

# %%
fig, ax = plt.subplots(figsize=(13, 3))
fig.suptitle("Top Artists- among all students",
             fontsize=10, fontweight="bold")

wc = build_wc(all_artists, colormap="RdPu", max_words=80, width=1200, height=600)
ax.imshow(wc, interpolation="bilinear")
ax.axis("off")

plt.tight_layout()
plt.savefig("artist_cloud_overall.png", dpi=150, bbox_inches="tight")
plt.show()
print("Saved -> artist_cloud_overall.png")
# Out:
# Saved -> artist_cloud_overall.png

# %% [markdown]
# ## 8. Artist clouds by college

# %%
cloud_grid(
    data_dict=college_artists,
    title="Top Artists by College",
    filename="artist_clouds_by_college.png",
    max_words=100,
)
# Out:
# Saved -> artist_clouds_by_college.png
